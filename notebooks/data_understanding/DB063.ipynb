# %%
import pandas as pd

# %%
import sys
sys.path.append('../utils/')
from utils.DataVisualization import DataVisualization

# %% [markdown]
# # Data Understanding:

# %% [markdown]
# ## DataFrame:

# %%
path = r'../../data/customers/CASTING_DB063.csv'
df = pd.read_csv(
    filepath_or_buffer=path,
    parse_dates=['VUF_DT'],
)
# Out:
# /tmp/ipykernel_21538/2331033163.py:2: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(

# %%
df.head(2)
# Out:
#                              VUF_CODIGO VUF_CODIGO_BOLETO  \
# 0  24A7937E-49F8-4ED1-B610-BB7995DC4106           1000000
# 1  8010F727-5671-48B5-8C23-E952CD191984           1000001
#
#                              UND_CODIGO                            FUN_CODIGO  \
# 0  B942EA32-EAFF-40ED-A728-0FE9C765F812  9BB64E05-6462-4CD6-8F2C-D2ADC9DA8765
# 1  31893136-A4A0-4472-BBB4-2EC814E5D86E  03CC7BB1-5F67-4569-AE52-3D359772B2F7
#
#       VUF_DT                            PRO_CODIGO  \
# 0 2022-05-22  3E5B7FB9-4844-44A6-B385-241017D41A28
# 1 2022-05-22  EB4285C5-A15D-4950-AB33-574F4A18F529
#
#                              CAT_CODIGO  VUF_QTBOLETO  VUF_QTPRODUTO  \
# 0  C179DA0E-8301-4088-8373-E26B6FEE99C3             1            1.0
# 1  C179DA0E-8301-4088-8373-E26B6FEE99C3             0            1.0
#
#    VUF_VLRBRUTOVENDA  VUF_VLRDESCONTO  VUF_VLRLIQFINAL  VUF_VLRTROCA  \
# 0             189.99              0.0           189.99           0.0
# 1             119.99              0.0           119.99           0.0
#
#        CLV_BANCO
# 0  CASTING_DB063
# 1  CASTING_DB063

# %% [markdown]
# ## Código:

# %%
class Casting(DataVisualization):
    pass

if __name__ == '__main__':
    casting = Casting()

# %% [markdown]
# ## Entendimento dos dados:

# %% [markdown]
# ### Topo do DataFrame:

# %%
df.head(3)
# Out:
#                              VUF_CODIGO VUF_CODIGO_BOLETO  \
# 0  24A7937E-49F8-4ED1-B610-BB7995DC4106           1000000
# 1  8010F727-5671-48B5-8C23-E952CD191984           1000001
# 2  0117A275-8992-4C64-A071-9D0B5C95A1A9           1000001
#
#                              UND_CODIGO                            FUN_CODIGO  \
# 0  B942EA32-EAFF-40ED-A728-0FE9C765F812  9BB64E05-6462-4CD6-8F2C-D2ADC9DA8765
# 1  31893136-A4A0-4472-BBB4-2EC814E5D86E  03CC7BB1-5F67-4569-AE52-3D359772B2F7
# 2  31893136-A4A0-4472-BBB4-2EC814E5D86E  03CC7BB1-5F67-4569-AE52-3D359772B2F7
#
#       VUF_DT                            PRO_CODIGO  \
# 0 2022-05-22  3E5B7FB9-4844-44A6-B385-241017D41A28
# 1 2022-05-22  EB4285C5-A15D-4950-AB33-574F4A18F529
# 2 2022-05-22  A986B967-2D6A-4CE0-82AA-EAEF42685001
#
#                              CAT_CODIGO  VUF_QTBOLETO  VUF_QTPRODUTO  \
# 0  C179DA0E-8301-4088-8373-E26B6FEE99C3             1            1.0
# 1  C179DA0E-8301-4088-8373-E26B6FEE99C3             0            1.0
# 2  B857F5D2-727A-4535-8DFA-8D3E2643117D             1            1.0
#
#    VUF_VLRBRUTOVENDA  VUF_VLRDESCONTO  VUF_VLRLIQFINAL  VUF_VLRTROCA  \
# 0             189.99              0.0           189.99           0.0
# 1             119.99              0.0           119.99           0.0
# 2              99.99              0.0            99.99           0.0
#
#        CLV_BANCO
# 0  CASTING_DB063
# 1  CASTING_DB063
# 2  CASTING_DB063

# %% [markdown]
# #### Fim do DataFrame:

# %%
df.tail(3)
# Out:
#                                    VUF_CODIGO VUF_CODIGO_BOLETO  \
# 2854640  DC5EA340-5D0D-494D-B571-CAA525D857A7  T-99997|V-811490
# 2854641  F5B7041A-B603-4BD9-8360-353EB39D9455  T-99998|V-717859
# 2854642  A9028C03-979D-4F9E-8808-298B221AFD46  T-99999|V-785776
#
#                                    UND_CODIGO  \
# 2854640  A01B0C0F-788B-4AD2-B85C-89A48861AAD4
# 2854641  4AD0F046-9FFB-4485-9159-467B99284292
# 2854642  4AD0F046-9FFB-4485-9159-467B99284292
#
#                                    FUN_CODIGO     VUF_DT  \
# 2854640  B1139D47-C738-4C15-BDE5-4F371D0B5F95 2022-03-24
# 2854641  090CD841-2F04-4518-89CC-6A4DC9BFFE6A 2022-03-24
# 2854642  090CD841-2F04-4518-89CC-6A4DC9BFFE6A 2022-03-24
#
#                                    PRO_CODIGO  \
# 2854640  3175089F-5AD1-4640-8061-D4BD254E0EA3
# 2854641  E5250DE0-31F5-4D59-AC22-BFE2294085BE
# 2854642  0362495C-C631-444F-B2D2-E939C588DE8B
#
#                                    CAT_CODIGO  VUF_QTBOLETO  VUF_QTPRODUTO  \
# 2854640  C179DA0E-8301-4088-8373-E26B6FEE99C3             0           -1.0
# 2854641  B857F5D2-727A-4535-8DFA-8D3E2643117D             0           -1.0
# 2854642  B857F5D2-727A-4535-8DFA-8D3E2643117D             0           -1.0
#
#          VUF_VLRBRUTOVENDA  VUF_VLRDESCONTO  VUF_VLRLIQFINAL  VUF_VLRTROCA  \
# 2854640                0.0              0.0              0.0           0.0
# 2854641                0.0              0.0              0.0           0.0
# 2854642                0.0              0.0              0.0           0.0
#
#              CLV_BANCO
# 2854640  CASTING_DB063
# 2854641  CASTING_DB063
# 2854642  CASTING_DB063

# %% [markdown]
# ### Lista de colunas do DataFrame:

# %%
list(df.columns)
# Out:
# ['VUF_CODIGO',
#  'VUF_CODIGO_BOLETO',
#  'UND_CODIGO',
#  'FUN_CODIGO',
#  'VUF_DT',
#  'PRO_CODIGO',
#  'CAT_CODIGO',
#  'VUF_QTBOLETO',
#  'VUF_QTPRODUTO',
#  'VUF_VLRBRUTOVENDA',
#  'VUF_VLRDESCONTO',
#  'VUF_VLRLIQFINAL',
#  'VUF_VLRTROCA',
#  'CLV_BANCO']

# %% [markdown]
# ### Dimensões do DataFrame:

# %%
casting.verificando_as_dimensões_do_dataframe(
    dataframe=df
)
# Out:
# Linhas: 2854643
# Colunas: 14

# %% [markdown]
# ### Describe numérico:

# %%
casting.descrição(
    dataframe=df,
    vertical=True
)
# Out:
#                        count                           mean  \
# VUF_DT               2854643  2022-11-14 17:07:25.922379008
# VUF_QTBOLETO       2854643.0                       0.581579
# VUF_QTPRODUTO      2854643.0                       0.832943
# VUF_VLRBRUTOVENDA  2854643.0                     125.472995
# VUF_VLRDESCONTO    2854643.0                       0.407216
# VUF_VLRLIQFINAL    2854643.0                     125.065789
# VUF_VLRTROCA       2854643.0                            0.0
#
#                                    min                  10%  \
# VUF_DT             2022-01-02 00:00:00  2022-03-17 00:00:00
# VUF_QTBOLETO                       0.0                  0.0
# VUF_QTPRODUTO                    -10.0                  1.0
# VUF_VLRBRUTOVENDA             -1099.99                  0.0
# VUF_VLRDESCONTO                -649.98                  0.0
# VUF_VLRLIQFINAL               -1099.99                  0.0
# VUF_VLRTROCA                       0.0                  0.0
#
#                                    15%                  25%  \
# VUF_DT             2022-04-21 00:00:00  2022-06-12 00:00:00
# VUF_QTBOLETO                       0.0                  0.0
# VUF_QTPRODUTO                      1.0                  1.0
# VUF_VLRBRUTOVENDA                 7.99                44.99
# VUF_VLRDESCONTO                    0.0                  0.0
# VUF_VLRLIQFINAL                   7.99                43.62
# VUF_VLRTROCA                       0.0                  0.0
#
#                                    50%                  75%  \
# VUF_DT             2022-11-30 00:00:00  2023-04-11 00:00:00
# VUF_QTBOLETO                       1.0                  1.0
# VUF_QTPRODUTO                      1.0                  1.0
# VUF_VLRBRUTOVENDA                110.0               179.99
# VUF_VLRDESCONTO                    0.0                  0.0
# VUF_VLRLIQFINAL                 109.99               179.99
# VUF_VLRTROCA                       0.0                  0.0
#
#                                    85%                  95%  \
# VUF_DT             2023-06-17 00:00:00  2023-08-28 00:00:00
# VUF_QTBOLETO                       1.0                  1.0
# VUF_QTPRODUTO                      1.0                  1.0
# VUF_VLRBRUTOVENDA               229.99               299.99
# VUF_VLRDESCONTO                    0.0                  0.0
# VUF_VLRLIQFINAL                 229.99               299.99
# VUF_VLRTROCA                       0.0                  0.0
#
#                                    99%                  max         std
# VUF_DT             2023-09-25 00:00:00  2023-10-01 00:00:00         NaN
# VUF_QTBOLETO                       1.0                  1.0      0.4933
# VUF_QTPRODUTO                      1.0                  1.0    0.553442
# VUF_VLRBRUTOVENDA               429.99              1199.99   104.84224
# VUF_VLRDESCONTO                   10.0               649.98     3.76305
# VUF_VLRLIQFINAL                 429.99              1199.99  104.517639
# VUF_VLRTROCA                       0.0                  0.0         0.0

# %% [markdown]
# ### Describe dos Objetos:

# %%
casting.descrição_object(
    dataframe=df,
    vertical=True
)
# Out:
#                      count   unique                                   top  \
# VUF_CODIGO         2854643  2854643  24A7937E-49F8-4ED1-B610-BB7995DC4106
# VUF_CODIGO_BOLETO  2854643  1879917                                781305
# UND_CODIGO         2854643       17  3E1708E9-0C02-41D9-B035-5728BA4A8F8D
# FUN_CODIGO         2854643      541  D8533F63-B4E1-4D50-B52C-C2BF90718956
# PRO_CODIGO         2854640    11228  3B3B9D31-3DC1-4C12-83F8-2C8E72887328
# CAT_CODIGO         2854643       26  B857F5D2-727A-4535-8DFA-8D3E2643117D
# CLV_BANCO          2854643        1                         CASTING_DB063
#
#                       freq
# VUF_CODIGO               1
# VUF_CODIGO_BOLETO       96
# UND_CODIGO          266403
# FUN_CODIGO           23096
# PRO_CODIGO           22799
# CAT_CODIGO          719303
# CLV_BANCO          2854643

# %% [markdown]
# ### Verificando Tipos:

# %%
casting.verificando_tipos(
    dataframe=df
)
# Out:
#                             Tipos
# VUF_CODIGO                 object
# VUF_CODIGO_BOLETO          object
# UND_CODIGO                 object
# FUN_CODIGO                 object
# VUF_DT             datetime64[ns]
# PRO_CODIGO                 object
# CAT_CODIGO                 object
# VUF_QTBOLETO                int64
# VUF_QTPRODUTO             float64
# VUF_VLRBRUTOVENDA         float64
# VUF_VLRDESCONTO           float64
# VUF_VLRLIQFINAL           float64
# VUF_VLRTROCA              float64
# CLV_BANCO                  object

# %% [markdown]
# ### Verificando `Nulos`:

# %%
casting.verificando_valores_nulos(
    dataframe=df
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_bf7ec">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bf7ec_level0_col0" class="col_heading level0 col0" >Quantidade</th>
#       <th id="T_bf7ec_level0_col1" class="col_heading level0 col1" >Porcentagem</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bf7ec_level0_row0" class="row_heading level0 row0" >VUF_CODIGO</th>
#       <td id="T_bf7ec_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_bf7ec_row0_col1" class="data row0 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_bf7ec_level0_row1" class="row_heading level0 row1" >VUF_CODIGO_BOLETO</th>
#       <td id="T_bf7ec_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_bf7ec_row1_col1" class="data row1 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_bf7ec_level0_row2" class="row_heading level0 row2" >UND_CODIGO</th>
#       <td id="T_bf7ec_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_bf7ec_row2_col1" class="data row2 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_bf7ec_level0_row3" class="row_heading level0 row3" >FUN_CODIGO</th>
#       <td id="T_bf7ec_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_bf7ec_row3_col1" class="data row3 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_bf7ec_level0_row4" class="row_heading level0 row4" >VUF_DT</th>
#       <td id="T_bf7ec_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_bf7ec_row4_col1" class="data row4 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_bf7ec_level0_row5" class="row_heading level0 row5" >PRO_CODIGO</th>
#       <td id="T_bf7ec_row5_col0" class="data row5 col0" >3</td>
#       <td id="T_bf7ec_row5_col1" class="data row5 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_bf7ec_level0_row6" class="row_heading level0 row6" >CAT_CODIGO</th>
#       <td id="T_bf7ec_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_bf7ec_row6_col1" class="data row6 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_bf7ec_level0_row7" class="row_heading level0 row7" >VUF_QTBOLETO</th>
#       <td id="T_bf7ec_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_bf7ec_row7_col1" class="data row7 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_bf7ec_level0_row8" class="row_heading level0 row8" >VUF_QTPRODUTO</th>
#       <td id="T_bf7ec_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_bf7ec_row8_col1" class="data row8 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_bf7ec_level0_row9" class="row_heading level0 row9" >VUF_VLRBRUTOVENDA</th>
#       <td id="T_bf7ec_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_bf7ec_row9_col1" class="data row9 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_bf7ec_level0_row10" class="row_heading level0 row10" >VUF_VLRDESCONTO</th>
#       <td id="T_bf7ec_row10_col0" class="data row10 col0" >0</td>
#       <td id="T_bf7ec_row10_col1" class="data row10 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_bf7ec_level0_row11" class="row_heading level0 row11" >VUF_VLRLIQFINAL</th>
#       <td id="T_bf7ec_row11_col0" class="data row11 col0" >0</td>
#       <td id="T_bf7ec_row11_col1" class="data row11 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_bf7ec_level0_row12" class="row_heading level0 row12" >VUF_VLRTROCA</th>
#       <td id="T_bf7ec_row12_col0" class="data row12 col0" >0</td>
#       <td id="T_bf7ec_row12_col1" class="data row12 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_bf7ec_level0_row13" class="row_heading level0 row13" >CLV_BANCO</th>
#       <td id="T_bf7ec_row13_col0" class="data row13 col0" >0</td>
#       <td id="T_bf7ec_row13_col1" class="data row13 col1" >0.00%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Visualização dos dados:

# %% [markdown]
# #### Identificando Outliers:

# %%
casting.gráfico_boxplot(
    dataframe=df[[
        "VUF_VLRLIQFINAL",
        "VUF_QTPRODUTO",
    ]],
    figsize=(16, 10),
    titulo='Identificando Outliers'
)

# %% [markdown]
# ### Mapa de calor - Verificando Correlação:

# %%
casting.gráfico_heatmap(
    dataframe=df[[
        "VUF_VLRBRUTOVENDA",
        "VUF_VLRLIQFINAL",
        "VUF_QTPRODUTO",
        "VUF_VLRDESCONTO",
    ]],
    titulo='Correlação entre as variáveis'
)

# %% [markdown]
# #### Gráfico de linha - Valor Bruto:

# %%
casting.gráfico_lineplot(
  dataframe=df,
  x='VUF_DT',
  y='VUF_VLRBRUTOVENDA',
  titulo='Valor Bruto ao longo do tempo'
)

# %% [markdown]
# #### Gráfico de linha - Valor líquido:

# %%
casting.gráfico_lineplot(
  dataframe=df,
  x='VUF_DT',
  y='VUF_VLRLIQFINAL',
  titulo='Valor líquido ao longo do tempo'
)

# %% [markdown]
# ## Perguntas:

# %%
# Criando serie temporal
df_question = df['VUF_VLRLIQFINAL']
df_question.index = df['VUF_DT']
df_question
# Out:
# VUF_DT
# 2022-05-22    189.99
# 2022-05-22    119.99
# 2022-05-22     99.99
# 2022-05-22    199.99
# 2022-05-22    249.99
#                ...
# 2022-03-24      0.00
# 2022-03-24      0.00
# 2022-03-24      0.00
# 2022-03-24      0.00
# 2022-03-24      0.00
# Name: VUF_VLRLIQFINAL, Length: 2854643, dtype: float64

# %% [markdown]
# #### Qual é a Quantidade de Transações por Mês?

# %%
# Agrupe por mês e conte o número de transações em cada mês
qtd_de_transacoes_por_mes = df_question.groupby(df_question.index.to_period('M')).size()

# Renomeie as colunas para que sejam mais descritivas
qtd_de_transacoes_por_mes = qtd_de_transacoes_por_mes.reset_index()
qtd_de_transacoes_por_mes.columns = ['Mês', 'Quantidade de Transações']

# Converta o período em uma representação de string do mês
qtd_de_transacoes_por_mes['Mês'] = qtd_de_transacoes_por_mes['Mês'].dt.strftime('%Y-%m')

# %% [markdown]
# ### Faturamento por mês:

# %%
casting.gráfico_linha_plot(
    data=qtd_de_transacoes_por_mes,
    x='Mês',
    y='Quantidade de Transações',
    figsize=(15,8),
    titulo='Quantidade de Transações por Mês',
    titulo_x='Mês',
    titulo_y='Quantidade de Transações',
)

# %% [markdown]
# #### Qual é o Faturamento por Mês?

# %%
# Agrupe por mês e conte o número de transações em cada mês
faturamento_por_mes = df_question.groupby(df_question.index.to_period('M')).sum()

# Renomeie as colunas para que sejam mais descritivas
faturamento_por_mes = faturamento_por_mes.reset_index()
faturamento_por_mes.columns = ['Mês', 'Faturamento']

# Converta o período em uma representação de string do mês
faturamento_por_mes['Mês'] = faturamento_por_mes['Mês'].dt.strftime('%Y-%m')

# %% [markdown]
# ### Faturamento por mês:

# %%
casting.gráfico_linha_plot(
    data=faturamento_por_mes,
    x='Mês',
    y='Faturamento',
    figsize=(15,8),
    titulo='Faturamento por Mês',
    titulo_x='Mês',
    titulo_y='Faturamento',
)

# %% [markdown]
# #### Histplot - Quantidade de Transações por Mês:

# %%
casting.gráfico_histplot(
    dataframe=qtd_de_transacoes_por_mes,
    coluna='Quantidade de Transações',
    titulo='Distribuição da Quantidade de Transações por Mês'
)

# %% [markdown]
# #### Histplot - Faturamento por Mês:

# %%
casting.gráfico_histplot(
    dataframe=faturamento_por_mes,
    coluna='Faturamento',
    titulo='Distribuição do Faturamento por Mês'
)
